# %%
from astropy.io import fits
from astropy.stats import sigma_clipped_stats
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from scipy.optimize import curve_fit
from scipy.special import factorial
from scipy.stats import poisson

# %%
lc_20to50_1 = fits.open('lc_20_to_50_Q0.lc')
lc_20to50_2 = fits.open('lc_20_to_50_Q1.lc')
lc_20to50_3 = fits.open('lc_20_to_50_Q2.lc')
lc_20to50_4 = fits.open('lc_20_to_50_Q3.lc')

lc_20to50 = [lc_20to50_1[1].data, lc_20to50_2[1].data, lc_20to50_3[1].data, lc_20to50_4[1].data]
lc_sum_20to50 = np.array(lc_20to50[0].field('RATE')+lc_20to50[1].field('RATE')+lc_20to50[2].field('RATE')+lc_20to50[3].field('RATE'))

# %%
plt.plot(lc_sum_20to50)
